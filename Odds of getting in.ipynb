# %% [markdown]
# ### Odds of getting your first choice
#
# Here we compare Hartford and suburban application versus offers to see what the "acceptance rate" is for each group.
#
# Applications and offers are separate spreadsheets, so this notebook aims to combine them on school name

# %%
import pandas as pd
from ct_schools import schools

# %% [markdown]
# ### Import both spreadsheets

# %%
offers = pd.read_excel("data/CLEANED - Offers By School By Grade 2017-18.xlsx",
                       skiprows=1,
                       usecols=[0,1,2,3,4,5])
#offers = offers.set_index(["Operator","School","Grade"])
offers.head()
# Out:
#   Operator                    School Grade   N N Hartford N Suburban
# 0      BPS  Global Experience Magnet     6  72         20         52
# 1      BPS  Global Experience Magnet     7   9        NaN          9
# 2      BPS  Global Experience Magnet     8  11        NaN         11
# 3      BPS  Global Experience Magnet     9  25         11         14
# 4      BPS  Global Experience Magnet    10  11        NaN         11

# %%
# Clean up the column names for offers
offers.columns = ["operator","school","grade","n_offers","n_offers_hartford","n_offers_suburban"]
offers.head()
# Out:
#   operator                    school grade n_offers n_offers_hartford  \
# 0      BPS  Global Experience Magnet     6       72                20
# 1      BPS  Global Experience Magnet     7        9               NaN
# 2      BPS  Global Experience Magnet     8       11               NaN
# 3      BPS  Global Experience Magnet     9       25                11
# 4      BPS  Global Experience Magnet    10       11               NaN
#
#   n_offers_suburban
# 0                52
# 1                 9
# 2                11
# 3                14
# 4                11

# %%
apps = pd.read_excel("data/CLEANED - First Chocie Apps By School By Grade 2017-18.xlsx",
                    skiprows=1)#.set_index(["Operator","School","Grade"])
apps.head()
# Out:
#   Operator          1st Choice School Grade     N N Hartford  N Suburban
# 0      BPS  Global Experience  Magnet     6  32.0          7        25.0
# 1      BPS   Global Experience Magnet     7  13.0        NaN         NaN
# 2      BPS   Global Experience Magnet     8   6.0        NaN         NaN
# 3      BPS   Global Experience Magnet     9  19.0         10         9.0
# 4      BPS   Global Experience Magnet    10   9.0        NaN         NaN

# %%
apps.columns = ["operator","school","grade","n_apps","n_apps_hartford","n_apps_suburban"]
apps.head()
# Out:
#   operator                     school grade  n_apps n_apps_hartford  \
# 0      BPS  Global Experience  Magnet     6    32.0               7
# 1      BPS   Global Experience Magnet     7    13.0             NaN
# 2      BPS   Global Experience Magnet     8     6.0             NaN
# 3      BPS   Global Experience Magnet     9    19.0              10
# 4      BPS   Global Experience Magnet    10     9.0             NaN
#
#    n_apps_suburban
# 0             25.0
# 1              NaN
# 2              NaN
# 3              9.0
# 4              NaN

# %% [markdown]
# ### Export data for use in open refine

# %%
apps["file"] = "apps"
offers["file"] = "offers"
pd.concat([apps,offers]).to_csv("data/FOR_REFINE_2.CSV",index=False)

# %% [markdown]
# ### Merge the data

# %%
def combine(apps_df,offers_df):
    return apps_df.join(offers_df,how="outer",rsuffix="_offers")

combined = combine(apps,offers)
combined.head()
# Out:
#   operator                     school grade  n_apps n_apps_hartford  \
# 0      BPS  Global Experience  Magnet     6    32.0               7
# 1      BPS   Global Experience Magnet     7    13.0             NaN
# 2      BPS   Global Experience Magnet     8     6.0             NaN
# 3      BPS   Global Experience Magnet     9    19.0              10
# 4      BPS   Global Experience Magnet    10     9.0             NaN
#
#    n_apps_suburban operator_offers             school_offers grade_offers  \
# 0             25.0             BPS  Global Experience Magnet            6
# 1              NaN             BPS  Global Experience Magnet            7
# 2              NaN             BPS  Global Experience Magnet            8
# 3              9.0             BPS  Global Experience Magnet            9
# 4              NaN             BPS  Global Experience Magnet           10
#
#   n_offers n_offers_hartford n_offers_suburban
# 0       72                20                52
# 1        9               NaN                 9
# 2       11               NaN                11
# 3       25                11                14
# 4       11               NaN                11

# %% [markdown]
# ### Check the merge
#
# Some rows in one spreadsheet didn't match rows in the other spreadsheet because the operator, school or grade didn't match up. Let's see where the problems were.

# %%
# Number of rows with apps but no offers data
no_offers = combined[combined["school_offers"].isnull()]
len(no_offers)
# Out:
# 23

# %%
print len(offers)
print len(apps)
# Out:
# 263
# 286

# %%
# There are definitely some OCR issues above. Let's use ct_schools.schools.closest() to try and find the closest match
def add_closest(df):
    ret = df.copy()
    ret["school_guess"] = ret["school"].apply(lambda x: schools.closest(x).iloc[0]["School Name"])
    ret["FUZZ"] = ret["school"].apply(lambda x: schools.closest(x).iloc[0]["FUZZ_RATIO"])

    return ret

apps = add_closest(apps)
offers = add_closest(offers)

# %%
# Here are the rows...
no_offers
# Out:
#     operator                                             school grade  n_apps  \
# 263      HPS  R.J. Kinsella Magnet School of the Performing ...    10    17.0
# 264      HPS  R.J. Kinsella Magnet School of the Performing ...    11     6.0
# 265      HPS  R.J. Kinsella Magnet School of the Performing ...    12     NaN
# 266      HPS                 Sport and Medical Sciences Academy     6   141.0
# 267      HPS                 Spo1i and Medical Sciences Academy     7    57.0
# 268      HPS                 Spo1i and Medical Sciences Academy     8    79.0
# 269      HPS                 Sport and Medical Sciences Academy     9   194.0
# 270      HPS                 Sport and Medical Sciences Academy    10    43.0
# 271      HPS                 Sport and Medical Sciences Academy    11    33.0
# 272      HPS                 Sport and Medical Sciences Academy    12     NaN
# 273      HPS                        STEM Magnet at Annie Fisher     K   101.0
# 274      HPS                        STEM Magnet at Annie Fisher     I    53.0
# 275      HPS                        STEM Magnet at Annie Fisher     2    43.0
# 276      HPS                        STEM Magnet at Annie Fisher     3    39.0
# 277      HPS                        STEM Magnet at Annie Fisher     4    34.0
# 278      HPS                        STEM Magnet at Annie Fisher     5    34.0
# 279      HPS                        STEM Magnet at Annie Fisher     6    21.0
# 280      HPS                        STEM Magnet at Annie Fisher     7    10.0
# 281      HPS                        STEM Magnet at Annie Fisher     8     7.0
# 282      HPS  University High School of Science and Engineering     9   200.0
# 283      HPS  University High School of Science and Engineering    10    39.0
# 284      HPS  University High School of Science and Engineering    11    31.0
# 285      HPS  University High School of Science and Engineering    12     NaN
#
#     n_apps_hartford  n_apps_suburban operator_offers school_offers  \
# 263               7             10.0             NaN           NaN
# 264             NaN              NaN             NaN           NaN
# 265             NaN              NaN             NaN           NaN
# 266              78             63.0             NaN           NaN
# 267              18             39.0             NaN           NaN
# 268              28             51.0             NaN           NaN
# 269             123             71.0             NaN           NaN
# 270              23             20.0             NaN           NaN
# 271              19             14.0             NaN           NaN
# 272             NaN              NaN             NaN           NaN
# 273              38             63.0             NaN           NaN
# 274              10             43.0             NaN           NaN
# 275               8             35.0             NaN           NaN
# 276              10             29.0             NaN           NaN
# 277              13             21.0             NaN           NaN
# 278              12             22.0             NaN           NaN
# 279               7             14.0             NaN           NaN
# 280             NaN              NaN             NaN           NaN
# 281             NaN              NaN             NaN           NaN
# 282              97            103.0             NaN           NaN
# 283              15             24.0             NaN           NaN
# 284              10             21.0             NaN           NaN
# 285             NaN              NaN             NaN           NaN
#
#     grade_offers n_offers n_offers_hartford n_offers_suburban
# 263          NaN      NaN               NaN               NaN
# 264          NaN      NaN               NaN               NaN
# 265          NaN      NaN               NaN               NaN
# 266          NaN      NaN               NaN               NaN
# 267          NaN      NaN               NaN               NaN
# 268          NaN      NaN               NaN               NaN
# 269          NaN      NaN               NaN               NaN
# 270          NaN      NaN               NaN               NaN
# 271          NaN      NaN               NaN               NaN
# 272          NaN      NaN               NaN               NaN
# 273          NaN      NaN               NaN               NaN
# 274          NaN      NaN               NaN               NaN
# 275          NaN      NaN               NaN               NaN
# 276          NaN      NaN               NaN               NaN
# 277          NaN      NaN               NaN               NaN
# 278          NaN      NaN               NaN               NaN
# 279          NaN      NaN               NaN               NaN
# 280          NaN      NaN               NaN               NaN
# 281          NaN      NaN               NaN               NaN
# 282          NaN      NaN               NaN               NaN
# 283          NaN      NaN               NaN               NaN
# 284          NaN      NaN               NaN               NaN
# 285          NaN      NaN               NaN               NaN

# %%
# Here are just the problematic school names
# And the schools.closest() match for each
problem_names = []
for n in no_offers["school"].unique(): 
    print "'" + n + "', '" + schools.closest(n).iloc[0]["School Name"] + "'"
# Out:
# 'R.J. Kinsella Magnet School of the Performing A1is', 'Kinsella Magnet School of Performing Arts'
# 'R.J. Kinsella Magnet School of the Performing Arts', 'Kinsella Magnet School of Performing Arts'
# 'Sport and Medical Sciences Academy', 'Sports and Medical Sciences Academy'
# 'Spo1i and Medical Sciences Academy', 'Sports and Medical Sciences Academy'
# 'STEM Magnet at Annie Fisher', 'STEM Magnet at Fisher School'
# 'University High School of Science and Engineering', 'University High School of Science and Engineering'

# %%
offers[offers["school"].str.contains("Kinsella")]["school"].unique()
# Out:
# array([u'R.J. Kinsella Magnet School of the Performing A1ts',
#        u'R.J. Kinsella Magnet School of the Performing Arts'],
#       dtype=object)

# %%
apps[apps["school"].str.contains("Kinsella")]["school"].unique()
# Out:
# array([u'R.J. Kinsella Magnet School of the Performing A1is',
#        u'R.J. Kinsella Magnet School of the Performing Arts'],
#       dtype=object)

# %%
len(apps) + len(offers)
# Out:
# 549
