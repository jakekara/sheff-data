# %%
import pandas as pd
from school_details import get_lat, add_location
from ct_schools.schools import closest

# %%
data_14 = pd.read_json("data/data.json")
schools = data_14[["School","lat","lng"]]
print schools.to_csv(sep="|",encoding='utf-8',index=False)
# Out:
# School|lat|lng
# Connecticut IB Academy|41.75284577900004,|-72.60449611
# Pathways Academy of Technology and Design|41.74056938200005,|-72.63770463
# Hartford Magnet Trinity College Academy|41.75125322700006,|-72.68669494
# Global Experience Magnet School|41.86972863700004,|-72.7352271
# Classical Magnet School|41.77334487200005,|-72.70027147
# Museum Academy|41.851007192000054,|-72.66673712
# Reggio Magnet School of the Arts|41.80167256800007,|-72.8190072
# Two Rivers Magnet Middle School|41.76024109900004,|-72.65997968
# Discovery Academy|41.73814668700004,|-72.67549714
# Public Safety Academy|41.949482670000066,|-72.60192537
# Academy of Aerospace and Engineering|41.75136059600004,|-72.68412374
# Two Rivers Magnet High School|41.75498712900003,|-72.66346746
# University of Hartford Magnet School|41.79337989800007,|-72.71630599
# Connecticut River Academy|41.75004990200006,|-72.64279689
# Academy of Aerospace and Engineering Elementary|41.643139388000066,|-72.66441061
# ...

# %%
# so, I have the data in a slightly different format this year. of course.
# so, I'm going to have to use this space to get it into a compatible format before moving on

#deseg_15 = pd.read_excel("data/Sheff Performance Calculation 2016-17.xlsx",
#                        skiprows=4,sheetname=2)
#deseg_15

deseg_15 = pd.read_excel("data/Sheff lottery.xlsx",
                       skiprows=2,sheetname='Sheet1')
deseg_15
# Out:
# /Applications/MAMP/htdocs/tdev/data/sheff-2016/venv/lib/python2.7/site-packages/pandas/util/_decorators.py:118: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   return func(*args, **kwargs)
#                                            Unnamed: 0  \
# 0                        Interdistrict Magnet Schools
# 1                                                 BPS
# 2                                                 NaN
# 3                                                EHPS
# 4                                                 HPS
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# ...

# %%
deseg_15.columns
# Out:
# Index([            u'Unnamed: 0',             u'Unnamed: 1',
#                u'Total Students',      u'Minority Students',
#                u'White Students',             u'% Minority',
#                       u'% White',             u'Unnamed: 7',
#              u'Total Students.1',          u'Black/ Latino',
#            u'Reduced- Isolation',        u'% Black/ Latino',
#          u'% Reduced- Isolation',            u'Unnamed: 13',
#                   u'Unnamed: 14',       u'Total Students.2',
#           u'Minority Students.1',       u'White Students.1',
#                  u'% Minority.1',              u'% White.1',
#                   u'Unnamed: 20',       u'Total Students.3',
#               u'Black/ Latino.1',   u'Reduced- Isolation.1',
#             u'% Black/ Latino.1', u'% Reduced- Isolation.1',
#                   u'Unnamed: 26',            u'Unnamed: 27',
#                      u'Capacity',              u'2016 Caps',
# ...

# %%
new_data = deseg_15[["Unnamed: 1", "% Black/ Latino.1", "% Reduced- Isolation.1"]].fillna(-1)
new_data.columns = "School","Black_Latino_Pct","Reduced_Isolation_Pct"
new_data = new_data[new_data["School"]!=-1]
new_data["School"] = new_data.apply(lambda x: x["School"].replace("*",""), axis=1)
new_data
# Out:
#                                                School  Black_Latino_Pct  \
# 1                 The Global Experience Magnet School              -1.0
# 2                   Wintonbury Early Childhood Magnet              -1.0
# 3                              Connecticut IB Academy              -1.0
# 4                          Betances Early Reading Lab              -1.0
# 5                                Betances STEM Magnet              -1.0
# 6                                     Breakthrough II              -1.0
# 7                   Breakthrough Magnet, South Campus              -1.0
# 8            Capital Community College Magnet Academy              -1.0
# 9                  Capital Preparatory Magnet Academy              -1.0
# 10                           Classical Magnet School               -1.0
# 11            Environmental Sciences @ Mary M. Hooker              -1.0
# 12                                 Great Path Academy              -1.0
# ...

# %%
# For the 2018 spreadsheet, the black and latino percent is null for everything
# so I'm going to calculate it
new_data["Black_Latino_Pct"] = 100 - new_data["Reduced_Isolation_Pct"]
new_data.head()
# Out:
#                                 School  Black_Latino_Pct  \
# 1  The Global Experience Magnet School              72.6
# 2    Wintonbury Early Childhood Magnet              55.7
# 3               Connecticut IB Academy              49.0
# 4           Betances Early Reading Lab              63.6
# 5                 Betances STEM Magnet              75.7
#
#    Reduced_Isolation_Pct
# 1                   27.4
# 2                   44.3
# 3                   51.0
# 4                   36.4
# 5                   24.3

# %%
# def get_lat(school_name):
    
#     print "'" + school_name + "'"
#     df = names[names["School_16"].replace(",","") == school_name.strip()]
#     #print df
#     if len(df.index) < 1:
#         ret = -1,-1
#     else:
#         ret = float(df["lat"].replace(",","")), float(df["lng"])
#     print ret
#     return ret

# new_data["lat"] = new_data.apply(lambda x: get_lat(x["School"])[0],axis=1)
# new_data["lng"] = new_data.apply(lambda x: get_lat(x["School"])[1],axis=1)

new_data = add_location(new_data, "School")

# %%
# Try adding the data another way

#new_data["guess"] = new_data["School"].apply(lambda x: closest(x).iloc[0]["School Name"])
#new_data

# %%
new_data["Black_Latino_Pct"] = new_data["Black_Latino_Pct"].round()
new_data["Reduced_Isolation_Pct"] = new_data["Reduced_Isolation_Pct"].round()

new_data
# Out:
#                                                School  Black_Latino_Pct  \
# 1                 The Global Experience Magnet School              73.0
# 2                   Wintonbury Early Childhood Magnet              56.0
# 3                              Connecticut IB Academy              49.0
# 4                          Betances Early Reading Lab              64.0
# 5                                Betances STEM Magnet              76.0
# 6                                     Breakthrough II              74.0
# 7                   Breakthrough Magnet, South Campus              75.0
# 8            Capital Community College Magnet Academy             101.0
# 9                  Capital Preparatory Magnet Academy              86.0
# 10                           Classical Magnet School               79.0
# 11            Environmental Sciences @ Mary M. Hooker              71.0
# 12                                 Great Path Academy              72.0
# ...

# %%
new_data.to_json(orient="records")
# Out:
# '[{"School":"The Global Experience Magnet School","Black_Latino_Pct":73.0,"Reduced_Isolation_Pct":27.0,"lat":41.869728637,"lng":-72.7352271},{"School":"Wintonbury Early Childhood Magnet","Black_Latino_Pct":56.0,"Reduced_Isolation_Pct":44.0,"lat":41.837399066,"lng":-72.74678679},{"School":"Connecticut IB Academy","Black_Latino_Pct":49.0,"Reduced_Isolation_Pct":51.0,"lat":41.752845779,"lng":-72.60449611},{"School":"Betances Early Reading Lab","Black_Latino_Pct":64.0,"Reduced_Isolation_Pct":36.0,"lat":41.759348105,"lng":-72.67311565},{"School":"Betances STEM Magnet","Black_Latino_Pct":76.0,"Reduced_Isolation_Pct":24.0,"lat":41.739859562,"lng":-72.67188386},{"School":"Breakthrough II","Black_Latino_Pct":74.0,"Reduced_Isolation_Pct":26.0,"lat":41.803897227,"lng":-72.7041756},{"School":"Breakthrough Magnet, South Campus","Black_Latino_Pct":75.0,"Reduced_Isolation_Pct":25.0,"lat":41.746999101,"lng":-72.7066482},{"School":"Capital Community College Magnet Academy","Black_Latino_Pct":101.0,"R
# ...

# %%
# drop schools without valid data
good_data = new_data[new_data["Reduced_Isolation_Pct"] >= 0]

# print how many rows are invalid
print len(new_data),"-",len(new_data) - len(good_data),  "=", len(good_data),
# Out:
# 54 - 6 = 48

# %%
# For some reason, the map uses a jsonp-type file, so I'll just go with that
# to make this update faster
open("data/data_2018.js","w").write("var theJson = " + good_data.to_json(orient="records") + ";")

# save it right to the viz folder
open("viz/integratedSchools/data_2018.js","w").write("var theJson = " + good_data.to_json(orient="records") + ";")

# %%
good_data
# Out:
#                                                School  Black_Latino_Pct  \
# 1                 The Global Experience Magnet School              73.0
# 2                   Wintonbury Early Childhood Magnet              56.0
# 3                              Connecticut IB Academy              49.0
# 4                          Betances Early Reading Lab              64.0
# 5                                Betances STEM Magnet              76.0
# 6                                     Breakthrough II              74.0
# 7                   Breakthrough Magnet, South Campus              75.0
# 9                  Capital Preparatory Magnet Academy              86.0
# 10                           Classical Magnet School               79.0
# 11            Environmental Sciences @ Mary M. Hooker              71.0
# 12                                 Great Path Academy              72.0
# 13            Hartford Magnet Trinity College Academy              74.0
# ...
